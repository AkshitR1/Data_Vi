# %%
import numpy as np  
import pandas as pd

# %%
import matplotlib.pyplot as plt
year = [1650, 1700, 1800, 1900, 2000]
GDP = [100, 500, 900, 1100, 1270]

plt.plot(year, GDP)

# %%
import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt
df_can = pd.read_excel("C:\\Users\\rtran\\Downloads\\Canada.xlsx",
    sheet_name='Canada by Citizenship',
    skiprows=range(20),
    skipfooter=2)
df_can.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...  1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...  3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...     0     0     1
# 4  Southern Europe  901   Developed regions     0  ...     0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# ...

# %%
df_can.iloc[87, [3, 4, 5, 6, 7, 8]]
# Out:
# AREA                      935
# AreaName                 Asia
# REG                       906
# RegName          Eastern Asia
# DEV                       901
# DevName     Developed regions
# Name: 87, dtype: object

# %%
df_can.plot(kind='area',
             figsize=(30, 10))
plt.title('Immigration Trend of Countries')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')

# %%
years = list(map(str, range(1980, 2014)))
df_least = df_can.tail(5)

# %%
all(isinstance(column, str) for column in df_can.columns)
# Out:
# False

# %%
years = list(map(str, range(1980, 2014)))

# %%
df_top5 = df_can.head()
df_top5 = df_top5[years].transpose()
df_top5.head()
# Out:
# Country  Afghanistan  Albania  Algeria  American Samoa  Andorra
# 1980              16        1       80               0        0
# 1981              39        0       67               1        0
# 1982              39        0       71               0        0
# 1983              47        0       69               0        0
# 1984              71        0       63               0        0

# %%
df_top5.index = df_top5.index.map(int)
df_top5.plot(kind='area',
             stacked=False,
             figsize=(20, 10))  

plt.title('Immigration Trend of First 5 Countries')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')

plt.show()

# %%
df_can['2013'].tail()
# Out:
# Country
# Viet Nam          2112
# Western Sahara       0
# Yemen              217
# Zambia              59
# Zimbabwe           407
# Name: 2013, dtype: int64

# %%
import numpy as np
count, bin_edges = np.histogram(df_can['2013'])
print(count) 
print(bin_edges)
# Out:
# [178  11   1   2   0   0   0   0   1   2]
# [    0.   3412.9  6825.8 10238.7 13651.6 17064.5 20477.4 23890.3 27303.2
#  30716.1 34129. ]

# %%
df_can['2013'].plot(kind='hist', figsize=(8, 5), xticks=bin_edges)
plt.title('Histogram of Immigration from 195 Countries in 2013')
plt.ylabel('Number of Countries')
plt.xlabel('Number of Immigrants')

plt.show()

# %%
df_iceland = df_can.loc['Iceland', years]
df_iceland.tail()
# Out:
# 2009    15
# 2010    30
# 2011    38
# 2012    42
# 2013    72
# Name: Iceland, dtype: object

# %%
df_iceland.plot(kind='bar', figsize=(10, 6), rot=90)

plt.xlabel('Year') 
plt.ylabel('Number of immigrants') 
plt.title('Icelandic immigrants to Canada from 1980 to 2013') 
plt.show()

# %%
df_ind = df_can.loc['India', years]
df_ind.plot(kind='bar', figsize=(10, 10), rot=90)
plt.xlabel('Year') 
plt.ylabel('Number of immigrants') 
plt.title('Indian immigrants to Canada from 1980 to 2013')

plt.show()

# %%
df_can.sort_values(by='2008', ascending=True, inplace=True)
df_top15 = df_can['2008'].tail(5)
df_top15.head()
df_top15.plot(kind='bar', figsize=(8,8),)
plt.xlabel='Immigrants'
plt.ylabel='Country'
plt.title='Immigrants for 2008'
plt.show()
